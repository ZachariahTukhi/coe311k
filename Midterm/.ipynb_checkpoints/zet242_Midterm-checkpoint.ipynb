# %% [markdown]
# # Intro
#
# This code is designed to analyze GDP data from the last 25 years. This data is from the U.S. Bureau of Economic Analysis (BEA) and represents the seasonally adjusted annual rate (SAAR) of real GDP growth in percentages. The three methods I will apply to this data are cubic spline interpolation, least squares linear regression, and polynomial fitting. Through this, I will analyze the best method to predict GDP.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

def setup_tridiagonal_matrix(x, y):
    n = len(x)
    h = np.diff(x)  # Step sizes: h[i] is x[i+1] - x[i]
    
    # Initialize the tridiagonal matrix coefficients for (n-2) internal equations
    A = np.zeros(n - 1)  # Subdiagonal
    B = np.zeros(n - 2)  # Main diagonal
    C = np.zeros(n - 1)  # Superdiagonal
    D = np.zeros(n - 2)  # Right-hand side vector
    
    # Populate the tridiagonal matrix coefficients
    for i in range(1, n - 1):

        A[i - 1] = h[i - 1] #Subdiagonal
        B[i - 1] = 2 * (h[i - 1] + h[i]) #Main diagonal
        C[i - 1] = h[i] #Superdiagonal
        D[i - 1] = 6 * (((y[i + 1] - y[i]) / h[i]) - (y[i] - y[i - 1]) / (h[i - 1])) #Right-hand side vector

    return A, B, C, D

def metrics(y_true, y_pred):
    # Mean Squared Error (MSE)
    mse = np.mean((y_true - y_pred)**2)
    # R-squared value
    ss_total = np.sum((y_true - np.mean(y_true))**2)
    ss_res = np.sum((y_true - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    
    return mse, r_squared

# %%
#Required functions below...

def LSQR(x, y):
    n = x.size
    x_sum = np.sum(x)
    y_sum = np.sum(y)
    x2_sum = np.sum(x**2)
    xy_sum = np.sum(x * y)
    
    m = (n*xy_sum - x_sum*y_sum) / (n*x2_sum - x_sum**2)
    c = (y_sum - m*x_sum) / n
    return m, c

def polynomial_fit(x, y, degree):
    n = len(x)
    X = np.zeros((n, degree + 1))
    for i in range(degree + 1):
        X[:, i] = x**i
    
    XTX = np.dot(X.T, X)
    XTy = np.dot(X.T, y)
    
    coef = np.linalg.solve(XTX, XTy)
    return coef 

def thomas_algorithm(a, b, c, d):
    n = len(b)
    # Forward elimination
    for i in range(1, n):
        w = a[i-1] / b[i-1]
        b[i] = b[i] - w * c[i-1]
        d[i] = d[i] - w * d[i-1]
    # Back substitution
    x = np.zeros(n)
    x[-1] = d[-1] / b[-1]
    
    for i in range(n-2, -1, -1):
        x[i] = (d[i] - c[i] * x[i+1]) / b[i]
    return x

def evaluate_spline(x_data, y_data, M, x_query):
    """M: second derivatives; M[0]=M[-1]=0 for natural spline"""
    n = len(x_data)
    h = np.diff(x_data) # step sizes
    i = np.searchsorted(x_data, x_query, side='right') - 1
    i = np.clip(i, 0, n - 2) # find interval
    hi = h[i]
    dx_left = x_query - x_data[i] # (x - xᵢ)
    dx_right = x_data[i+1] - x_query # (xᵢ₊₁ - x)
    S = (
        (M[i] / (6*hi)) * dx_right**3 + # Term 1
        (M[i+1] / (6*hi)) * dx_left**3 + # Term 2
        (y_data[i] /hi - M[i] *hi/6) * dx_right + # Term 3
        (y_data[i+1] /hi - M[i+1] *hi/6) * dx_left # Term 4
    )
    return S

# %%
#Data cell
raw_data = [
    ("2010 Q1", 1.7), ("2011 Q1", 0.1), ("2012 Q1", 2.3), ("2013 Q1", 2.7),
    ("2014 Q1", 1.7), ("2014 Q3", 5.0), ("2015 Q2", 3.0), ("2016 Q1", 1.5),
    ("2016 Q3", 3.5), ("2016 Q4", 1.8), ("2017 Q1", 1.3), ("2018 Q1", 2.5),
    ("2019 Q1", 3.1), ("2020 Q1", -5.1), ("2020 Q2", -28.1), ("2020 Q3", 33.8),
    ("2021 Q1", 6.3), ("2022 Q1", -1.6), ("2023 Q2", 2.4), ("2023 Q4", 3.3)
]

def quarter_to_decimal(q_str):
    year_part, q_part = q_str.split()
    year = int(year_part)
    quarter_decimal = (int(q_part[1]) - 1) * 0.25
    return year + quarter_decimal
x_data = np.arange(1, len(raw_data) + 1)
y_data = np.array([d[1] for d in raw_data])

# %% [markdown]
# # Part A -- Cubic Spline Interpolation

# %% [markdown]
# Part 1

# %%
#Setup and Solve System
a, b, c, d = setup_tridiagonal_matrix(x_data, y_data)
M_internal = thomas_algorithm(a, b, c, d)

#Boundary Conditions
M = np.zeros(len(x_data))
M[1:-1] = M_internal

#Plotting
x_plot_CS = x_data
y_plot_CS = evaluate_spline(x_data, y_data, M, x_plot_CS)

#Graphing
plt.plot(x_plot_CS, y_plot_CS, label='Cubic Spline Curve', color='red', linewidth=2)
plt.scatter(x_data, y_data, color='blue', label='Original Data Points', zorder=5)
plt.title("Interpolation using Thomas Algorithm (Natural Spline)")
plt.xlabel("Time Index")
plt.ylabel("GDP growth %")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Part 1 explained:
# There are 4 unknown coefficients in this data set, A,B,C, and D. Each internal knot must follow both first and second derivate continuity for the spline. The boundary conditions that define a natural spline are the endpoints of the overall data having their second derivative equal to zero.

# %% [markdown]
# Part 2

# %%
x_full = np.linspace(x_data[0], x_data[-1], 55)
y_full = np.array([evaluate_spline(x_data, y_data, M, xq) for xq in x_full])

plt.scatter(x_full, y_full, color='blue', label='Interpolated 55 Quarters', s=20, zorder=5)
plt.plot(x_full, y_full, label='Cubic Spline Curve', color='red', linewidth=2)

plt.title("Full 55-Quarter Dataset Generated via Cubic Spline")
plt.xlabel("Time Index (Quarters from 2010 Q1)")
plt.ylabel("GDP growth %")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Part 2 explained:
# The interpolant is visually smoother, and it seems reasonable in terms of following the rough trend of the cubic spline to determine the missing GDP growth %'s in each quarter.

# %% [markdown]
# Part 3

# %% [markdown]
# Part 3 explained:
# The Runge phenomenon is the oscillations of interpolated points at the edges of an interval in high-degree polynomial fittings. Exact interpolation via Cubic Spline avoids this error when facing extreme outliers in a data set. A smoothing spline would be preferable here primarily due to how it reduces the influence of the outlier, reducing the local oscillations caused by extreme outliers, which would make the overall data interpolation better.

# %% [markdown]
# # Part B -- Polynomial & Least Squares Comparison

# %% [markdown]
# Part 1

# %%
plt.figure()
beta = polynomial_fit(x_data, y_data, 4)
x_plot = np.linspace(1, 20, 100)
# Evaluate the polynomial: beta[0] + beta[1]*x + beta[2]*x^2 ...
y_poly = sum(beta[i] * x_plot**i for i in range(len(beta)))

plt.scatter(x_data, y_data, color='blue')
plt.plot(x_plot_CS, y_plot_CS, label='Cubic Spline Curve', color='red', linewidth=2)
plt.plot(x_plot, y_poly, color='green', label='4th Degree Polynomial Fit')
plt.title("4th Degree Polynomial Fit vs Cubic Spline")
plt.xlabel("Time Index")
plt.ylabel("GDP growth %")
plt.legend()
plt.show()

# %% [markdown]
# Part 1 explained:
# The 4th degree polynomial fit better captures the overall trend and is not skewed too much by the outliers around 2020. Meanwhile, the Cubic Spline best reproduces each individual data point per quarter due to its exact nature. Approximation allows for the ability to make predictions for the future under the assumption of similar conditions, but interpolation allows for an exact measurement and value of data, which works best for something that has a consistant fluctuation that follows a patter. However, interpolation does not allow for predictions of future data of data sets that have variances that do not follow a specific pattern, such as GDP.

# %% [markdown]
# Part 2

# %%
indices_to_remove = [13, 14, 15, 16] 
x_LSQR = np.delete(x_data, indices_to_remove)
y_LSQR = np.delete(y_data, indices_to_remove)
m, c = LSQR(x_LSQR, y_LSQR)

plt.figure(figsize=(10, 5))
plt.scatter(x_LSQR, y_LSQR, color='blue', label='Stable Data')
plt.scatter(x_data[indices_to_remove], y_data[indices_to_remove], color='gray', alpha=0.3, label='Outliers (Removed)')
plt.plot(x_LSQR, m*x_LSQR + c, color='red', linewidth=2, label=f'Trend: {m:.2f}x + {c:.2f}')

plt.title("Linear Regression (Excluding 2020 Volatility)")
plt.xlabel("Time Index")
plt.ylabel("GDP Growth %")
plt.legend()
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# Part 2 explained:
# After removing the outliers from the COVID quarters, the slope of the overall data ends up being -.02. A linear trend does not make economic sense for this data primarily because GDP over long periods of time have factors that can cause exponential fluctuations, which a linear trend does not encapsulate. A linear trend requires the assumtion that an economy and its GDP are fluctuated only at a constant rate, which is not the case due to exponential growth and compounding factors in GDP growth as a whole.

# %% [markdown]
# # Part C -- Method Justification

# %% [markdown]
# Part 1

# %% [markdown]
# Part 1 explained:
# For a policymaker who needs to estimate GDP growth for a quarter between two known data points, it would be best to use a Cubic Spline fitting. This is because a cubic spline offers a smoother result between the two, and it is more accurate at interpolating points between two known data point because it is not greatly affected by outliers far off in the dataset.

# %% [markdown]
# Part C addendum

# %%
# Generate synthetic data
def generate_data(n):
    x = np.linspace(0, 10, n)
    y = np.sin(x) + 0.1 * np.random.randn(n)
    return x, y

# Cubic spline wrapper
def cubic_spline(x, y):
    A, B, C, D = setup_tridiagonal_matrix(x, y)
    
    # Adjust sizes for Thomas algorithm
    a = A[:-1]
    b = B.copy()
    c = C[1:]
    d = D.copy()
    
    M_internal = thomas_algorithm(a, b, c, d)
    
    # Natural spline boundary conditions
    M = np.zeros(len(x))
    M[1:-1] = M_internal
    
    return M

# Timing function
def measure_time(func, *args):
    start = time.perf_counter()
    func(*args)
    end = time.perf_counter()
    return end - start

# Input sizes
sizes = [10, 50, 100, 200, 500, 1000, 2000]

lsqr_times = []
poly_times = []
spline_times = []

degree = 4

for n in sizes:
    x, y = generate_data(n)

    # LSQR
    t_lsqr = measure_time(LSQR, x, y)
    lsqr_times.append(t_lsqr)

    # Polynomial fit
    t_poly = measure_time(polynomial_fit, x, y, degree)
    poly_times.append(t_poly)

    # Cubic spline
    t_spline = measure_time(cubic_spline, x, y)
    spline_times.append(t_spline)

# Plot results (log-log for Big-O visualization)
plt.figure(figsize=(8, 6))

plt.loglog(sizes, lsqr_times, 'o-', label='LSQR (Linear Fit)')
plt.loglog(sizes, poly_times, 's-', label='Polynomial Fit (deg=3)')
plt.loglog(sizes, spline_times, '^-', label='Cubic Spline')

plt.xlabel('Input Size (n)')
plt.ylabel('Time (seconds)')
plt.title('Empirical Big-O Comparison')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Part C addendum explained:
# Big O notation is a way of measuring time and space complexity of an algorithms. The time it takes to run a Cubic Spline takes longer than a Polynomial Fitting, which is still longer than a Least Squares Regression. However, despite this, for this data, the difference in negligible and the decreased time to calculate this data provides little value, thus I would not change my recommendation on using Cubic Spline.

# %% [markdown]
# # Conclusion
# Overall the Cubic Spline method worked the best for interpolation because it matches exact data points accurately and avoids fluctuations from outliers when determining the data between known points. Meanwhile, the Polynomial Fitting method worked best for trend analysis because it provided a consistant trend to follow that allowed for the data to be affected by a variety of patterns and change overtime, which made it best for predicting where a trend might go. Each of methods used had their own strengths when it came to analyzing this data set. The least squares regression method allowed for prediction of where a trend might go under the constraints of the data not being exponential or compound in nature. The polynomial fitting method allowed for prediction of where a trend might go whilst allowing for shifts from exponential and compount factors. However, polynomial fitting was poor at interpolating data around outliers. The cubic spline method allowed for the best interpolation of data points due to how it intersected every point and followed a smooth path. However, due to how it intersects every point, it is poor at predicting where the trend of the data may go in the future.

# %% [markdown]
# Citing: used wikipedia to figure out what the Runge Phenomenom is. Additionally, used functions from class slides. I used AI tool, google Gemini to check my code after being written to ensure it runs without numeral miscalcuations and accomplishes the task properly by asking it to review my code and understanding of each section.
