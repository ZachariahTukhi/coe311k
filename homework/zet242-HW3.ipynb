# %%
import numpy as np
import math

sin_counter = []
sin_calc = []

for x in range(0,10):
    for n in range (0,5):
        sin_counter.append(((x)**(2*n+1))/(math.factorial(2*n+1)))
        sin_calc.append(sum(sin_counter))
