# %% [markdown]
# # Challenge A

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

def metrics(y_true, y_pred):
    # Mean Squared Error (MSE)
    mse = np.mean((y_true - y_pred)**2)
    # R-squared value
    ss_total = np.sum((y_true - np.mean(y))**2)
    ss_res = np.sum((y_true - y_pred)**2)
    r_squared = 1 - (ss_res / ss_total)
    
    return mse, r_squared

# %%
import numpy as np
import matplotlib.pyplot as plt

#data
x_values = 10 * np.sort(np.random.rand(10))
y_values = 10 * np.random.rand(10)

#solve with lsqr
A = np.vstack([x_values, np.ones(len(x_values))]).T
m, c = np.linalg.lstsq(A, y_values, rcond=None)[0]
y_pred_lsqr = m * x_values + c

#solve with polyfit
poly_coeffs = np.polyfit(x_values, y_values, 3)
p_cubic = np.poly1d(poly_coeffs)
y_pred_poly = p_cubic(x_values)

#metrics of methods
mse_lsqr, r2_lsqr = metrics(y_values, y_pred_lsqr)
mse_poly, r2_poly = metrics(y_values, y_pred_poly)

#Determining better fit
if mse_poly<mse_lsqr:
    better_method = "Cubic Polyfit"
else:
    better_method = "Linear Least Squares"

#graphing
plt.scatter(x_values, y_values, color='blue', label='Data Points')

x_range = np.linspace(x_values.min(), x_values.max(), 100)
plt.plot(x_range, m * x_range + c, color='red', label=f'Linear LSQ (MSE: {mse_lsqr})')
plt.plot(x_range, p_cubic(x_range), color='green', label=f'Cubic Polyfit (MSE: {mse_poly})')

plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Manual Evaluation: Linear vs. Cubic Fit')
plt.legend()

#evaluation
print(f"Linear LSQ - MSE: {mse_lsqr}, R2: {r2_lsqr}")
print(f"Cubic Polyfit - MSE: {mse_poly}, R2: {r2_poly}")
print(f"The better fit is: {better_method}")
# Out:
# Linear LSQ - MSE: 5.547195993785169, R2: 0.9721210337545012
# Cubic Polyfit - MSE: 5.494428687150388, R2: 0.9723862304344428
# The better fit is: Cubic Polyfit

# %% [markdown]
# # Challenge B

# %%
degrees = [9, 8, 7, 6, 5, 4, 3, 2, 1] 

print(f"{'Degree':<8} | {'MSE':<12} | {'R-Squared':<10} | {'Status'}")
print("-" * 55)

plt.figure(figsize=(12, 8))
plt.scatter(x_values, y_values, color='black', label='Random Data Points', zorder=5)
x_range = np.linspace(x_values.min(), x_values.max(), 500)

for d in sorted(degrees):
    #Fits
    coeffs = np.polyfit(x_values, y_values, d)
    p = np.poly1d(coeffs)
    
    #Evaluate metrics
    y_pred = p(x_values)
    mse, r2 = metrics(y_values, y_pred)
    
    # Labeling
    if d == 1: status = "Underfit"
    elif d == 3: status = "Cubic (Base)"
    elif d >= 8: status = "Overfit"
    else: status = "Cranking..."

    print(f"{d:<8} | {mse:12.4f} | {r2:10.4f} | {status}")
    
    if d in [1, 2, 3, 4, 5, 6, 7, 8, 9]:
        plt.plot(x_range, p(x_range), label=f'Deg {d} (R²: {r2:.2f})')

plt.ylim(y_values.min() - 2, y_values.max() + 2)
plt.title('Cranking Polynomial Degrees on Random Data')
plt.legend()
plt.show()
# Out:
# Degree   | MSE          | R-Squared  | Status
# -------------------------------------------------------
# 1        |       5.5472 |     0.9721 | Underfit
# 2        |       5.5329 |     0.9722 | Cranking...
# 3        |       5.4944 |     0.9724 | Cubic (Base)
# 4        |       3.7829 |     0.9810 | Cranking...
# 5        |       3.7827 |     0.9810 | Cranking...
# 6        |       3.5025 |     0.9824 | Cranking...
# 7        |       1.7966 |     0.9910 | Cranking...
# 8        |       0.2247 |     0.9989 | Overfit
# 9        |       0.0000 |     1.0000 | Overfit

# %% [markdown]
# # Challenge C

# %%
degree = 3 
V = np.vander(x_values, N=degree+1, increasing=False)
coeffs_vander = np.linalg.lstsq(V, y_values, rcond=None)[0]
y_pred_vander = np.dot(V, coeffs_vander)
mse_vander, r2_vander = metrics(y_values, y_pred_vander)
print(f"Vandermonde Fit (degree={degree}) - MSE: {mse_vander}, R2: {r2_vander}")

plt.scatter(x_values, y_values, color='blue', label='Data Points')
plt.plot(x_range, np.poly1d(coeffs_vander)(x_range), 'red', label=f'Vandermonde (MSE={mse_vander:.2f})')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Vandermonde Polynomial Fit')
plt.legend()
plt.show()
# Out:
# Vandermonde Fit (degree=3) - MSE: 4.259242716298431, R2: 0.6659630879073526
