# %%
import numpy as np
import matplotlib.pyplot as plt
import random
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
print("X:")
print(X)
print("Y:")
print(Y)
print("A:")
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Y:
# [1.2 2.8 3.6 4.5 5.1]
# A:
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
#Part 1 graphed out
plt.figure()
plt.scatter(X,Y)

x = np.linspace(X.min(),X.max(),100)
y = m*x+c

plt.plot(x, y, color='red', label='LSQR')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('LSQR of data from part 1')
plt.legend()
plt.show()

# %%
#part 2

plt.figure()

#getting values
x_values = np.random.rand(10)
x_values = 10*np.sort(x_values)
y_values = 10*np.random.rand(10)

A = np.vstack([x_values, np.ones(len(x_values))]).T
m, c = np.linalg.lstsq(A, y_values, rcond=None)[0]

plt.scatter(x_values,y_values)

x = np.linspace(x_values.min(),x_values.max(),100)
y = m*x+c

plt.plot(x, y, color='red', label='LSQRL') 
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('LSQR of random data points')
plt.legend()
plt.show()

plt.show()

# %% [markdown]
# The data does not fit nearly as well due to the data given not being all too related to one another due to them being random.

# %%
#part 3
# random linear function
realM = np.random.uniform(-10,10)
realB = np.random.uniform(-10,10)

#Data
X = np.arange(0, 1.01, 0.01)
noise = np.random.uniform(-1, 1, size=X.shape)
Y = realM * X + realB + noise

#solving LSQR
A = np.vstack([X, np.ones(len(X))]).T
PredictedM, PredictedB = np.linalg.lstsq(A, Y, rcond=None)[0]

#Residuals
PredictedY = PredictedM * X + PredictedB
residual = Y - PredictedY
absolute_residuals = np.abs(residual)

max_abs = np.argmax(absolute_residuals)
min_abs = np.argmin(absolute_residuals)


Xmax = np.argmax(residual)
Xmin = np.argmin(residual)

# Outputed equations
print(f"Original Equation:  y = {realM}x + {realB:}")
print(f"Predicted Equation: y = {PredictedM}x + {PredictedB}")
print("")

#Residuals
print(f"Max Residual of {residual[Xmax]} at X = {X[Xmax]}")
print(f"Min Residual of {residual[Xmin]} at X = {X[Xmin]}")
print('')
print(f"Largest absolute Residual of {absolute_residuals[max_abs]} at X = {X[max_abs]}")
print(f"Smallest absolute Residual of {absolute_residuals[min_abs]} at X = {X[min_abs]}")

# Graphing
plt.scatter(X, Y, color='blue', label='Data Points including with noise')
plt.plot(X, PredictedY, color='red', label=f'Predicted values using LSQR')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('LSQR with noise')
plt.legend()
plt.show()
# Out:
# Original Equation:  y = 7.333138010670371x + -7.043169691048783
# Predicted Equation: y = 7.325202641089417x + -7.1767011159138105
#
# Max Residual of 1.0969386665365217 at X = 0.91
# Min Residual of -0.8539279240220186 at X = 0.31
#
# Largest absolute Residual of 1.0969386665365217 at X = 0.91
# Smallest absolute Residual of 0.015595026575941695 at X = 0.33

# %% [markdown]
# I had to look up how to calculate residuals off of the arrays using argmin and argmax to find the index/location. I asked the google search bar the phrase and used the AI overview.
#
# "How do I find the index of the largest and smallest value in a numpy array"
