# %%
import numpy as np
import time
#Implmentation function of jacobi
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
import numpy as np
#Implmentation function of gauss_seidel
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %% [markdown]
# # CHALLENGE A

# %%
#Existing arrays I need to solve for challenge a
A = np.array([[10,-1,2,0,0],[-1,11,-1,3,0],[2,-1,10,-1,0],[0,3,-1,8,-2],[0,0,0,-2,9]])
#b needs to be a float to avoid data leakages
b = np.array([14.,30.,26.,25.,37.])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

# %%
#Solve challenge using jacobi
start_time = time.time()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
end_time = time.time()
print(end_time-start_time)
# Out:
# Solution: [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations: 18
# 0.007780313491821289

# %%
#Solve using Gauss Seidel
start_time = time.time()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
end_time = time.time()
print(end_time-start_time)
# Out:
# Solution: [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations: 10
# 0.005202293395996094

# %%
#Check for similarity to real result using np.linalg.solve()
print(np.linalg.solve(A,b))
# Out:
# [1. 2. 3. 4. 5.]

# %% [markdown]
# Found time functions off of stackoverflow. Both methods in Challenge A do converge, with Jacobi doing it in 18 iterations in 0.007780313491821289 seconds and Gauss-Seidel doing it in 10 iterations in 0.005202293395996094 seconds.

# %% [markdown]
# # CHALLENGE B

# %%
#Existing arrays I need to solve for challenge b
A = np.array([[1,2,3,0,0],[2,1,2,3,0],[3,2,1,2,3],[0,3,2,1,2],[0,0,3,2,1]])
#b needs to be a float to avoid data leakages
b = np.array([14.,22.,33.,26.,22.])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

# %%
#Solve using jacobi
start_time = time.time()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
end_time = time.time()
print(end_time-start_time)
# Out:
# Solution: [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Iterations: 100
# 0.017574071884155273

# %%
#Solve using Gauss Seidel
start_time = time.time()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
end_time = time.time()
print(end_time-start_time)
# Out:
# Solution: [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Iterations: 100
# 0.01644611358642578

# %%
#Check for similarity to real result using np.linalg.solve()
print(np.linalg.solve(A,b))
# Out:
# [1. 2. 3. 4. 5.]

# %% [markdown]
# Found time functions off of stackoverflow. Challenge B is not convergent due to it not being diagonally dominant. However, it is still solveable using numpy.linalg.solve().
